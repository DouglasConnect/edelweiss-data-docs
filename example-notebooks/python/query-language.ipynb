# %% [markdown]
# # EdelweissData Query Language
#
# This notebook shows the python client library equivalents to the raw HTTP calls described in the [query language](https://edelweissdata.com/docs/query-language) walkthrough on the offical EdelweissData documentation website.
#
# EdelweissData™ has a rich Query language that allows you to filter and sort both queries to find datasets as well as queries for the actual data of an individual dataset.
#
# To make it easy to get familiar with the Query Language this walkthrough is divided into two sections: an overview of the Query language and then an enumeration of the different types of expressions with examples.
#
# A useful way to get familiar with the Query Language is also to view a dataset in the [EdelweissData™ DataExplorer](https://edelweissdata.com/dataset/8dde2785-8a2a-4847-80b8-982a691954d6:128?q=%7B%7D), filter the data by filling search fields in the UI and ordering it by clicking the icons and then clicking the "API" button in the top right corner to copy/paste the code including the Query expression to filter & order data rows just like you see it in the DataExplorer.

# %% [markdown]
# ## API initialization
#
# (See the [setup notebook](setup.ipynb) for details on how to install, initialize and authorize the library)

# %%
from edelweiss_data import API, QueryExpression as Q

# Set this to the url of the Edelweiss Data server you want to interact with
edelweiss_api_url = 'https://api.edelweissdata.com'

api = API(edelweiss_api_url)

# %%
# Setup to be able to query the Our world in Data dataset:
datasetid = "b55b229d-6338-4e41-a507-0cf4d3297b54"
version = 117

dataset = api.get_published_dataset(datasetid, version)

# %%
import altair

# %% [markdown]
# ## Overview
#
# The EdelweissData python client API provides convenience methods to construct the various parts of the query language and takes care of translating it correctly to the underlying JSON serialisation. As an example, this is how to filter rows in a datasets to only those that have the text value "Germany" in the column called "location" (see below for the results of running this query on a real dataset).
#
# Note that when importing the edelweiss_data library, the QueryExpression class that contains all the method helpers is often aliased to Q because it is used a lot

# %%
from edelweiss_data import API, QueryExpression as Q

filter = Q.exact_search(Q.column("location"), "Germany")

# %% [markdown]
# ## Applications
#
# The Query Language can be used with EdelweissData™ API Endpoints that queries for datasets ([/datasets](https://api.edelweissdata.com/docs/index.html#operations-Published-getPublishedDatasetsViaPost)) as well as those that query for data of an individual dataset ([/datasets/{datasetId}/versions/{version}/data](https://api.edelweissdata.com/docs/index.html#operations-Published-postPublishedDatasetData)). In both cases it can be used to specify the sorting of the data and to filter rows. In the sorting case the Expression has to evaluate to a numeric or textual value (i.e. not a boolean), for the filtering the expression has to evaluate to a boolean value (i.e. whether or not to include a row).
#
# In the interactive examples below we will have two query targets. For querying the data of a dataset we will use the COVID-19 data compiled by [Our world in data](https://ourworldindata.org), filtered to various countries etc. You can look at the dataset in the browser in the [EdelweissData™ DataExplorer](https://edelweissdata.com/dataset/b55b229d-6338-4e41-a507-0cf4d3297b54:117?q=%7B%7D). For the datasets query we will query for all public datasets at [edelweissdata.com](https://edelweissdata.com/datasets)
#
# # Elements of the Query Language
#
# ## Values
#
# Values are the simplest elements of a Query and are used verbatim (i.e. there is no special escaping etc necessary, they are simply JSON values). You can either use string values (in quotes, e.g. `"Germany"`), numbers (e.g. `4` or `3.2` or `2.384e12`), booleans (`True` or `False`), arrays (python arrays, i.e. `[2.0, 3.0, 4.0]`) or objects (python dicts, e.g. `{"some-key": "some-value"}`). Of these, strings and numbers are by far used the most. Arrays can be useful for contains queries (where you want to know if a column of an array data type contains the values of the given array). Objects are only used occasionally when doing queries for datasets that include parts of the metadata that can of course contain nested objects.
#
# ## Columns
#
# Column expression reference a given column by name and return the value in the column of the given name. Columns are expressions can be constructed with the QueryExpression helper `QueryExpression.column()`:

# %%
filter = Q.exact_search(Q.column("location"), "Germany")
data_for_germany = dataset.get_data(condition = filter)
data_for_germany
# Out:
#            iso_code continent location        date  total_cases  new_cases  \
# 9152  9151      DEU    Europe  Germany  2019-12-31            0          0
# 9153  9152      DEU    Europe  Germany  2020-01-01            0          0
# 9154  9153      DEU    Europe  Germany  2020-01-02            0          0
# 9155  9154      DEU    Europe  Germany  2020-01-03            0          0
# 9156  9155      DEU    Europe  Germany  2020-01-04            0          0
# ...    ...      ...       ...      ...         ...          ...        ...
# 9385  9384      DEU    Europe  Germany  2020-08-20       228621       1707
# 9386  9385      DEU    Europe  Germany  2020-08-21       230948       2327
# 9387  9386      DEU    Europe  Germany  2020-08-22       232082       1134
# 9388  9387      DEU    Europe  Germany  2020-08-23       232864        782
# 9389  9388      DEU    Europe  Germany  2020-08-24       233575        711
#
#       new_cases_smoothed  total_deaths  new_deaths  ...  aged_70_older  \
# 9152                 NaN             0           0  ...         15.957
# 9153                 NaN             0           0  ...         15.957
# 9154                 NaN             0           0  ...         15.957
# 9155                 NaN             0           0  ...         15.957
# 9156                 NaN             0           0  ...         15.957
# ...                  ...           ...         ...  ...            ...
# 9385            1128.143          9253          10  ...         15.957
# 9386            1253.143          9260           7  ...         15.957
# 9387            1223.857          9267           7  ...         15.957
# 9388            1233.000          9269           2  ...         15.957
# 9389            1265.857          9272           3  ...         15.957
#
#       gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 9152       45229.245             None                156.139
# 9153       45229.245             None                156.139
# 9154       45229.245             None                156.139
# 9155       45229.245             None                156.139
# 9156       45229.245             None                156.139
# ...              ...              ...                    ...
# 9385       45229.245             None                156.139
# 9386       45229.245             None                156.139
# 9387       45229.245             None                156.139
# 9388       45229.245             None                156.139
# 9389       45229.245             None                156.139
#
#       diabetes_prevalence  female_smokers  male_smokers  \
# 9152                 8.31            28.2          33.1
# 9153                 8.31            28.2          33.1
# 9154                 8.31            28.2          33.1
# 9155                 8.31            28.2          33.1
# 9156                 8.31            28.2          33.1
# ...                   ...             ...           ...
# 9385                 8.31            28.2          33.1
# 9386                 8.31            28.2          33.1
# 9387                 8.31            28.2          33.1
# 9388                 8.31            28.2          33.1
# 9389                 8.31            28.2          33.1
#
#      handwashing_facilities  hospital_beds_per_thousand  life_expectancy
# 9152                   None                           8            81.33
# 9153                   None                           8            81.33
# 9154                   None                           8            81.33
# 9155                   None                           8            81.33
# 9156                   None                           8            81.33
# ...                     ...                         ...              ...
# 9385                   None                           8            81.33
# 9386                   None                           8            81.33
# 9387                   None                           8            81.33
# 9388                   None                           8            81.33
# 9389                   None                           8            81.33
#
# [238 rows x 41 columns]

# %%
altair.Chart(data_for_germany).mark_circle().encode(
        x="date:T",
        y="new_cases",
        color="location",
        tooltip=["location", "date", "new_cases", "new_deaths"]
    ).properties(width=1000)
# Out:
# alt.Chart(...)

# %% [markdown]
# Queries that query for datasets can use JSONpaths to map fragments of the metadata into new columns with names supplied with the JSONpath. To distinguish between always existing columns like the dataset name (`name`) or the creation timestamp (`created`) and user defined column names, there exist the special `QueryExpression.system_column()` method that is used for system specified columns, e.g. to search for a dataset with the name "COVID-19 complete dataset by Our World In Data" the following expression would be used to indicate that we want to search in the system defined name column, not a column with the same name that was constructed with a JSONpath query:

# %%
filter_datasets_by_name = Q.exact_search(Q.system_column("name"), "COVID-19 complete dataset by Our World In Data")

# %%
datasets = api.get_published_datasets(condition = filter_datasets_by_name)
datasets
# Out:
#                                                                                         dataset
# id                                   version
# b55b229d-6338-4e41-a507-0cf4d3297b54 143      <PublishedDataset 'b55b229d-6338-4e41-a507-0cf...

# %%
datasets.iloc[0].dataset.name
# Out:
# 'COVID-19 complete dataset by Our World In Data'

# %% [markdown]
# ## Text searches
#
# Three text search functions exist in EdelweissData™: `Q.search_anywhere()` which searches in any text-like column;`Q.exact_search()` which searches in a given column for an exact string value; and `Q.fuzzy_search()` which does a more lenient search within a given column for a string (matchings substrings). Text searches result in a boolean value.
#
# ### Search anywhere

# %%
filter = Q.search_anywhere("United")

data_united = dataset.get_data(condition = filter)

altair.Chart(data_united).mark_circle().encode(
        x="date:T",
        y="new_cases",
        color="location",
        tooltip=["location", "date", "new_cases", "new_deaths"]
    ).properties(width=1000)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Exact search

# %%
filter = Q.exact_search(Q.column("location"), "United States")

data_united_states = dataset.get_data(condition = filter)

altair.Chart(data_united_states).mark_circle().encode(
        x="date:T",
        y="new_cases",
        color="location",
        tooltip=["location", "date", "new_cases", "new_deaths"]
    ).properties(width=1000)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Fuzzy search

# %%
filter = Q.fuzzy_search(Q.column("location"), "States")

data_states = dataset.get_data(condition = filter)

altair.Chart(data_states).mark_circle().encode(
        x="date:T",
        y="new_cases",
        color="location",
        tooltip=["location", "date", "new_cases", "new_deaths"]
    ).properties(width=1000)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Relations
#
# Relations express the usual comparisons and in the EdelweissData python library are modelled as infix operators: equality (`==`), greaterThan (`>`), greaterThanOrEqual(`>=`), lessThan (`<`), lessThanOrEqual(`<=`) and unequal(`!=`). All of these take two arguments that are then compared with the result being a boolean value.

# %%
filter = (Q.column("new_cases") == 100)

data_100_cases = dataset.get_data(condition = filter)

altair.Chart(data_100_cases).mark_circle().encode(
        x="date:T",
        y="new_cases",
        color="location",
        tooltip=["location", "date", "new_cases", "new_deaths"]
    ).properties(width=1000)
# Out:
# alt.Chart(...)

# %%
filter = (Q.column("new_cases") > 50000)

data_above_50000 = dataset.get_data(condition = filter)

altair.Chart(data_above_50000).mark_circle().encode(
        x="date:T",
        y="new_cases",
        color="location",
        tooltip=["location", "date", "new_cases", "new_deaths"]
    ).properties(width=1000)
# Out:
# alt.Chart(...)

# %% [markdown]
# #### Contains/ContainedIn
#
# In addition to the usual suspects above there exist two special relations, `Q.contains` and `Q.contained_in` that check if the first argument is contains the second (`contains`) or vice versa (`contained_in`)

# %%
filter_by_keyword = Q.contains(Q.column("keywords"), "covid-19")

datasets = api.get_published_datasets(condition = filter_by_keyword, columns = [("keywords", "$.keywords[*]", "xsd:string")])
datasets
# Out:
#                                                                                         dataset  \
# id                                   version
# 8dde2785-8a2a-4847-80b8-982a691954d6 131      <PublishedDataset '8dde2785-8a2a-4847-80b8-982...
# dade0fa0-782d-47fa-84bd-9e3388bf9580 134      <PublishedDataset 'dade0fa0-782d-47fa-84bd-9e3...
# 21842e38-ad7d-454f-9bfb-e58e79ffdf8b 137      <PublishedDataset '21842e38-ad7d-454f-9bfb-e58...
# 87f93af6-fd7a-4c25-961a-07e53fb97250 137      <PublishedDataset '87f93af6-fd7a-4c25-961a-07e...
# f67ffafd-702b-4705-b33d-8258f5090b57 138      <PublishedDataset 'f67ffafd-702b-4705-b33d-825...
# 72421b77-78e8-4fad-9e3b-33956585e515 137      <PublishedDataset '72421b77-78e8-4fad-9e3b-339...
# b55b229d-6338-4e41-a507-0cf4d3297b54 143      <PublishedDataset 'b55b229d-6338-4e41-a507-0cf...
#
#                                                                                     keywords
# id                                   version
# 8dde2785-8a2a-4847-80b8-982a691954d6 131                  [covid-19, cases, deaths, Germany]
# dade0fa0-782d-47fa-84bd-9e3388bf9580 134               [covid-19, cases, deaths, by country]
# 21842e38-ad7d-454f-9bfb-e58e79ffdf8b 137               [covid-19, cases, deaths, by country]
# 87f93af6-fd7a-4c25-961a-07e53fb97250 137               [covid-19, cases, deaths, by country]
# f67ffafd-702b-4705-b33d-8258f5090b57 138               [covid-19, cases, deaths, by country]
# 72421b77-78e8-4fad-9e3b-33956585e515 137                      [covid-19, cases, deaths, USA]
# b55b229d-6338-4e41-a507-0cf4d3297b54 143      [covid-19, cases, deaths, by country, testing]

# %% [markdown]
# ## Logical operators
#
# The usual logical operators are supported - because python allows to override the bitwise variants but not the logical operators, you have to use the infix bitwise not, and and or variants: not (`~` operator), and (`&` operator) and or (`|` operator). All require boolean arguments and evaluate in turn to a boolean value.

# %%
filter = (~ (Q.column("new_cases") < 50000))

data_above_50000 = dataset.get_data(condition = filter)

altair.Chart(data_above_50000).mark_circle().encode(
        x="date:T",
        y="new_cases",
        color="location",
        tooltip=["location", "date", "new_cases", "new_deaths"]
    ).properties(width=1000)
# Out:
# alt.Chart(...)

# %%
filter = (Q.column("new_cases") > 2000) & (Q.exact_search(Q.column("location"), "Italy") | Q.exact_search(Q.column("location"), "Germany"))

data_above_2000_germany_or_italy = dataset.get_data(condition = filter)

altair.Chart(data_above_2000_germany_or_italy).mark_circle().encode(
        x="date:T",
        y="new_cases",
        color="location",
        tooltip=["location", "date", "new_cases", "new_deaths"]
    ).properties(width=1000)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Special functions
#
# There are a few additional capabilities that fall outside the range of the usual query vocabulary. These revolve around specific domain types, notably the SMILES column type for the chemical structure notation of the same name.
#
# ### Tanimoto Similarity
#
# `tanimoto_similarity` allows you to calculate the [Tanimoto Similarity](https://en.wikipedia.org/wiki/Jaccard_index#Tanimoto_similarity_and_distance) between the molecular fingerprints of the two arguments (fingerprinting is currently not customizable and defaults to rdkit fingerprints with default settings). Both arguments should evaluate to a SMILES chemical structure (either string values that will be converted implicitly or a column with datatype SMILES). The expression evaluates to a score between 0 and 1 with 0 being dissimilar and 1 being entirely identically fingerprints. `tanimoto_similarity` can thus be used either directly in `order_by` clauses or as a filter when used in a relation (e.g. > 0.7). When an orderBy clause with a tanimotoSimilarity is active, the values returned for each row in the first referenced column will be augmented with the calculated similarity score (i.e. the json object that is returned for SMILES columns that is always an object with one key for the original value and one for the canonicalized SMILES string will be augmented with an additional `similarity` key that contains the numerical similarity value)

# %%
filter = Q.tanimoto_similarity("C=S(C)C", Q.column("SMILES")) > 0.2

chemical_dataset = api.get_published_dataset("2940e662-0ba1-4d8a-927d-03689808e99d", "latest")
benzene_similar = chemical_dataset.get_data(condition = filter)
benzene_similar
# Out:
#       Gene Compound code  Replicate log10(Concentration) Concentration unit  \
# 1    h36B4          DMSO          1                 None               None
# 2    h36B4          DMSO          2                 None               None
# 9     h1A1          DMSO          1                 None               None
# 10    h1A1          DMSO          2                 None               None
# 17    h1A2          DMSO          1                 None               None
# 18    h1A2          DMSO          2                 None               None
# 25    h1B1          DMSO          1                 None               None
# 26    h1B1          DMSO          2                 None               None
# 33    h2A6          DMSO          1                 None               None
# 34    h2A6          DMSO          2                 None               None
# 41    h2E1          DMSO          1                 None               None
# 42    h2E1          DMSO          2                 None               None
# 49    h3A4          DMSO          1                 None               None
# 50    h3A4          DMSO          2                 None               None
# 57    hGST          DMSO          1                 None               None
# 58    hGST          DMSO          2                 None               None
# 65    hNAT          DMSO          1                 None               None
# 66    hNAT          DMSO          2                 None               None
# 73   hSULT          DMSO          1                 None               None
# 74   hSULT          DMSO          2                 None               None
# 81    hUGT          DMSO          1                 None               None
# 82    hUGT          DMSO          2                 None               None
# 132   hGST          DMSO          2                 None               None
#
#     Compound type Gene type Well     Ct  \
# 1           Blank   Control   A1  14.95
# 2           Blank   Control   B1  15.69
# 9           Blank      Test   A2  37.60
# 10          Blank      Test   B2  38.02
# 17          Blank      Test   A3    NaN
# 18          Blank      Test   B3    NaN
# 25          Blank      Test   A4  30.89
# 26          Blank      Test   B4  32.06
# 33          Blank      Test   A5  27.83
# 34          Blank      Test   B5  27.82
# 41          Blank      Test   A6  31.58
# 42          Blank      Test   B6  32.01
# 49          Blank      Test   A7  27.15
# 50          Blank      Test   B7  27.14
# 57          Blank      Test   A8    NaN
# 58          Blank      Test   B8    NaN
# 65          Blank      Test   A9  26.90
# 66          Blank      Test   B9  26.89
# 73          Blank      Test  A10  29.60
# 74          Blank      Test  B10  30.72
# 81          Blank      Test  A11  24.11
# 82          Blank      Test  B11  24.41
# 132         Blank      Test  D12    NaN
#
#                                               SMILES   Blank  Delta Ct  \
# 1    {'original': 'CS(=O)C', 'canonical': 'CS(C)=O'}  15.320     0.370
# 2    {'original': 'CS(=O)C', 'canonical': 'CS(C)=O'}  15.320    -0.370
# 9    {'original': 'CS(=O)C', 'canonical': 'CS(C)=O'}  37.810     0.210
# 10   {'original': 'CS(=O)C', 'canonical': 'CS(C)=O'}  37.810    -0.210
# 17   {'original': 'CS(=O)C', 'canonical': 'CS(C)=O'}     NaN       NaN
# 18   {'original': 'CS(=O)C', 'canonical': 'CS(C)=O'}     NaN       NaN
# 25   {'original': 'CS(=O)C', 'canonical': 'CS(C)=O'}  31.475     0.585
# 26   {'original': 'CS(=O)C', 'canonical': 'CS(C)=O'}  31.475    -0.585
# 33   {'original': 'CS(=O)C', 'canonical': 'CS(C)=O'}  27.825    -0.005
# 34   {'original': 'CS(=O)C', 'canonical': 'CS(C)=O'}  27.825     0.005
# 41   {'original': 'CS(=O)C', 'canonical': 'CS(C)=O'}  31.795     0.215
# 42   {'original': 'CS(=O)C', 'canonical': 'CS(C)=O'}  31.795    -0.215
# 49   {'original': 'CS(=O)C', 'canonical': 'CS(C)=O'}  27.145    -0.005
# 50   {'original': 'CS(=O)C', 'canonical': 'CS(C)=O'}  27.145     0.005
# 57   {'original': 'CS(=O)C', 'canonical': 'CS(C)=O'}     NaN       NaN
# 58   {'original': 'CS(=O)C', 'canonical': 'CS(C)=O'}     NaN       NaN
# 65   {'original': 'CS(=O)C', 'canonical': 'CS(C)=O'}  26.895    -0.005
# 66   {'original': 'CS(=O)C', 'canonical': 'CS(C)=O'}  26.895     0.005
# 73   {'original': 'CS(=O)C', 'canonical': 'CS(C)=O'}  30.160     0.560
# 74   {'original': 'CS(=O)C', 'canonical': 'CS(C)=O'}  30.160    -0.560
# 81   {'original': 'CS(=O)C', 'canonical': 'CS(C)=O'}  24.260     0.150
# 82   {'original': 'CS(=O)C', 'canonical': 'CS(C)=O'}  24.260    -0.150
# 132  {'original': 'CS(=O)C', 'canonical': 'CS(C)=O'}     NaN       NaN
#
#          Fold  Fold control  Normalized fold  Mean fold   SD fold
# 1    1.292353      1.292353         1.000000   1.000000  0.000000
# 2    0.773782      0.773782         1.000000   1.000000  0.000000
# 9    1.156688      1.292353         0.895025   1.006156  0.157163
# 10   0.864537      0.773782         1.117287   1.006156  0.157163
# 17        NaN      1.292353              NaN        NaN       NaN
# 18        NaN      0.773782              NaN        NaN       NaN
# 25   1.500039      1.292353         1.160704   1.011125  0.211536
# 26   0.666649      0.773782         0.861546   1.011125  0.211536
# 33   0.996540      1.292353         0.771105   1.033972  0.371750
# 34   1.003472      0.773782         1.296840   1.033972  0.371750
# 41   1.160704      1.292353         0.898132   1.005777  0.152232
# 42   0.861546      0.773782         1.113422   1.005777  0.152232
# 49   0.996540      1.292353         0.771105   1.033972  0.371750
# 50   1.003472      0.773782         1.296840   1.033972  0.371750
# 57        NaN      1.292353              NaN        NaN       NaN
# 58        NaN      0.773782              NaN        NaN       NaN
# 65   0.996540      1.292353         0.771105   1.033972  0.371750
# 66   1.003472      0.773782         1.296840   1.033972  0.371750
# 73   1.474269      1.292353         1.140764   1.008685  0.186788
# 74   0.678302      0.773782         0.876606   1.008685  0.186788
# 81   1.109569      1.292353         0.858565   1.011650  0.216494
# 82   0.901250      0.773782         1.164734   1.011650  0.216494
# 132       NaN      0.773782              NaN        NaN       NaN

# %% [markdown]
# ### Substructure search
# `Q.substructure_search` let's you find chemical substructures where the first argument is searched for in the second. Both argument should evaluate to a SMILES chemical structure (either string values that will be converted implicitly or a column with datatype SMILES). `substructure_search` evaluates to a boolean value.

# %%
filter = Q.substructure_search("c1ccccc1", Q.column("SMILES"))

chemical_dataset = api.get_published_dataset("2940e662-0ba1-4d8a-927d-03689808e99d", "latest")
benzene_similar = chemical_dataset.get_data(condition = filter)
benzene_similar
# Out:
#      Gene Compound code  Replicate  log10(Concentration) Concentration unit  \
# 3   h36B4          TCDD          1                    -8              mol/L
# 4   h36B4          TCDD          2                    -8              mol/L
# 5   h36B4           Rif          1                    -4              mol/L
# 6   h36B4           Rif          2                    -4              mol/L
# 11   h1A1          TCDD          1                    -8              mol/L
# 12   h1A1          TCDD          2                    -8              mol/L
# 13   h1A1           Rif          1                    -4              mol/L
# 14   h1A1           Rif          2                    -4              mol/L
# 19   h1A2          TCDD          1                    -8              mol/L
# 20   h1A2          TCDD          2                    -8              mol/L
# 21   h1A2           Rif          1                    -4              mol/L
# 22   h1A2           Rif          2                    -4              mol/L
# 27   h1B1          TCDD          1                    -8              mol/L
# 28   h1B1          TCDD          2                    -8              mol/L
# 29   h1B1           Rif          1                    -4              mol/L
# 30   h1B1           Rif          2                    -4              mol/L
# 35   h2A6          TCDD          1                    -8              mol/L
# 36   h2A6          TCDD          2                    -8              mol/L
# 37   h2A6           Rif          1                    -4              mol/L
# 38   h2A6           Rif          2                    -4              mol/L
# 43   h2E1          TCDD          1                    -8              mol/L
# 44   h2E1          TCDD          2                    -8              mol/L
# 45   h2E1           Rif          1                    -4              mol/L
# 46   h2E1           Rif          2                    -4              mol/L
# 51   h3A4          TCDD          1                    -8              mol/L
# 52   h3A4          TCDD          2                    -8              mol/L
# 53   h3A4           Rif          1                    -4              mol/L
# 54   h3A4           Rif          2                    -4              mol/L
# 59   hGST          TCDD          1                    -8              mol/L
# 60   hGST          TCDD          2                    -8              mol/L
# 61   hGST           Rif          1                    -4              mol/L
# 62   hGST           Rif          2                    -4              mol/L
# 67   hNAT          TCDD          1                    -8              mol/L
# 68   hNAT          TCDD          2                    -8              mol/L
# 69   hNAT           Rif          1                    -4              mol/L
# 70   hNAT           Rif          2                    -4              mol/L
# 75  hSULT          TCDD          1                    -8              mol/L
# 76  hSULT          TCDD          2                    -8              mol/L
# 77  hSULT           Rif          1                    -4              mol/L
# 78  hSULT           Rif          2                    -4              mol/L
# 83   hUGT          TCDD          1                    -8              mol/L
# 84   hUGT          TCDD          2                    -8              mol/L
# 85   hUGT           Rif          1                    -4              mol/L
# 86   hUGT           Rif          2                    -4              mol/L
#
#    Compound type Gene type Well     Ct  \
# 3           Test   Control   C1  15.43
# 4           Test   Control   D1  15.43
# 5           Test   Control   E1  15.26
# 6           Test   Control   F1  15.07
# 11          Test      Test   C2  35.80
# 12          Test      Test   D2  35.48
# 13          Test      Test   E2  36.74
# 14          Test      Test   F2  38.12
# 19          Test      Test   C3    NaN
# 20          Test      Test   D3    NaN
# 21          Test      Test   E3    NaN
# 22          Test      Test   F3    NaN
# 27          Test      Test   C4  28.79
# 28          Test      Test   D4  28.46
# 29          Test      Test   E4  31.95
# 30          Test      Test   F4  32.19
# 35          Test      Test   C5  28.55
# 36          Test      Test   D5  28.64
# 37          Test      Test   E5  27.37
# 38          Test      Test   F5  27.86
# 43          Test      Test   C6  31.01
# 44          Test      Test   D6  31.14
# 45          Test      Test   E6  31.31
# 46          Test      Test   F6  31.42
# 51          Test      Test   C7  26.70
# 52          Test      Test   D7  26.61
# 53          Test      Test   E7  26.66
# 54          Test      Test   F7  26.25
# 59          Test      Test   C8    NaN
# 60          Test      Test   D8    NaN
# 61          Test      Test   E8  42.83
# 62          Test      Test   F8  42.74
# 67          Test      Test   C9  26.66
# 68          Test      Test   D9  26.83
# 69          Test      Test   E9  26.71
# 70          Test      Test   F9  26.21
# 75          Test      Test  C10  29.29
# 76          Test      Test  D10  29.77
# 77          Test      Test  E10  28.70
# 78          Test      Test  F10  28.21
# 83          Test      Test  C11  24.30
# 84          Test      Test  D11  24.31
# 85          Test      Test  E11  24.81
# 86          Test      Test  F11  24.69
#
#                                                SMILES   Blank  Delta Ct  \
# 3   {'original': 'C1=C2C(=CC(=C1Cl)Cl)OC3=CC(=C(C=...  15.320    -0.110
# 4   {'original': 'C1=C2C(=CC(=C1Cl)Cl)OC3=CC(=C(C=...  15.320    -0.110
# 5   {'original': 'CC1C=CC=C(C(=O)NC2=C(C(=C3C(=C2O...  15.320     0.060
# 6   {'original': 'CC1C=CC=C(C(=O)NC2=C(C(=C3C(=C2O...  15.320     0.250
# 11  {'original': 'C1=C2C(=CC(=C1Cl)Cl)OC3=CC(=C(C=...  37.810     2.010
# 12  {'original': 'C1=C2C(=CC(=C1Cl)Cl)OC3=CC(=C(C=...  37.810     2.330
# 13  {'original': 'CC1C=CC=C(C(=O)NC2=C(C(=C3C(=C2O...  37.810     1.070
# 14  {'original': 'CC1C=CC=C(C(=O)NC2=C(C(=C3C(=C2O...  37.810    -0.310
# 19  {'original': 'C1=C2C(=CC(=C1Cl)Cl)OC3=CC(=C(C=...     NaN       NaN
# 20  {'original': 'C1=C2C(=CC(=C1Cl)Cl)OC3=CC(=C(C=...     NaN       NaN
# 21  {'original': 'CC1C=CC=C(C(=O)NC2=C(C(=C3C(=C2O...     NaN       NaN
# 22  {'original': 'CC1C=CC=C(C(=O)NC2=C(C(=C3C(=C2O...     NaN       NaN
# 27  {'original': 'C1=C2C(=CC(=C1Cl)Cl)OC3=CC(=C(C=...  31.475     2.685
# 28  {'original': 'C1=C2C(=CC(=C1Cl)Cl)OC3=CC(=C(C=...  31.475     3.015
# 29  {'original': 'CC1C=CC=C(C(=O)NC2=C(C(=C3C(=C2O...  31.475    -0.475
# 30  {'original': 'CC1C=CC=C(C(=O)NC2=C(C(=C3C(=C2O...  31.475    -0.715
# 35  {'original': 'C1=C2C(=CC(=C1Cl)Cl)OC3=CC(=C(C=...  27.825    -0.725
# 36  {'original': 'C1=C2C(=CC(=C1Cl)Cl)OC3=CC(=C(C=...  27.825    -0.815
# 37  {'original': 'CC1C=CC=C(C(=O)NC2=C(C(=C3C(=C2O...  27.825     0.455
# 38  {'original': 'CC1C=CC=C(C(=O)NC2=C(C(=C3C(=C2O...  27.825    -0.035
# 43  {'original': 'C1=C2C(=CC(=C1Cl)Cl)OC3=CC(=C(C=...  31.795     0.785
# 44  {'original': 'C1=C2C(=CC(=C1Cl)Cl)OC3=CC(=C(C=...  31.795     0.655
# 45  {'original': 'CC1C=CC=C(C(=O)NC2=C(C(=C3C(=C2O...  31.795     0.485
# 46  {'original': 'CC1C=CC=C(C(=O)NC2=C(C(=C3C(=C2O...  31.795     0.375
# 51  {'original': 'C1=C2C(=CC(=C1Cl)Cl)OC3=CC(=C(C=...  27.145     0.445
# 52  {'original': 'C1=C2C(=CC(=C1Cl)Cl)OC3=CC(=C(C=...  27.145     0.535
# 53  {'original': 'CC1C=CC=C(C(=O)NC2=C(C(=C3C(=C2O...  27.145     0.485
# 54  {'original': 'CC1C=CC=C(C(=O)NC2=C(C(=C3C(=C2O...  27.145     0.895
# 59  {'original': 'C1=C2C(=CC(=C1Cl)Cl)OC3=CC(=C(C=...     NaN       NaN
# 60  {'original': 'C1=C2C(=CC(=C1Cl)Cl)OC3=CC(=C(C=...     NaN       NaN
# 61  {'original': 'CC1C=CC=C(C(=O)NC2=C(C(=C3C(=C2O...     NaN       NaN
# 62  {'original': 'CC1C=CC=C(C(=O)NC2=C(C(=C3C(=C2O...     NaN       NaN
# 67  {'original': 'C1=C2C(=CC(=C1Cl)Cl)OC3=CC(=C(C=...  26.895     0.235
# 68  {'original': 'C1=C2C(=CC(=C1Cl)Cl)OC3=CC(=C(C=...  26.895     0.065
# 69  {'original': 'CC1C=CC=C(C(=O)NC2=C(C(=C3C(=C2O...  26.895     0.185
# 70  {'original': 'CC1C=CC=C(C(=O)NC2=C(C(=C3C(=C2O...  26.895     0.685
# 75  {'original': 'C1=C2C(=CC(=C1Cl)Cl)OC3=CC(=C(C=...  30.160     0.870
# 76  {'original': 'C1=C2C(=CC(=C1Cl)Cl)OC3=CC(=C(C=...  30.160     0.390
# 77  {'original': 'CC1C=CC=C(C(=O)NC2=C(C(=C3C(=C2O...  30.160     1.460
# 78  {'original': 'CC1C=CC=C(C(=O)NC2=C(C(=C3C(=C2O...  30.160     1.950
# 83  {'original': 'C1=C2C(=CC(=C1Cl)Cl)OC3=CC(=C(C=...  24.260    -0.040
# 84  {'original': 'C1=C2C(=CC(=C1Cl)Cl)OC3=CC(=C(C=...  24.260    -0.050
# 85  {'original': 'CC1C=CC=C(C(=O)NC2=C(C(=C3C(=C2O...  24.260    -0.550
# 86  {'original': 'CC1C=CC=C(C(=O)NC2=C(C(=C3C(=C2O...  24.260    -0.430
#
#         Fold  Fold control  Normalized fold  Mean fold   SD fold
# 3   0.926588      0.926588         1.000000   1.000000  0.000000
# 4   0.926588      0.926588         1.000000   1.000000  0.000000
# 5   1.042466      1.042466         1.000000   1.000000  0.000000
# 6   1.189207      1.189207         1.000000   1.000000  0.000000
# 11  4.027822      0.926588         4.346939   4.886678  0.763306
# 12  5.028053      0.926588         5.426417   4.886678  0.763306
# 13  2.099433      1.042466         2.013911   1.346107  0.944418
# 14  0.806642      1.189207         0.678302   1.346107  0.944418
# 19       NaN      0.926588              NaN        NaN       NaN
# 20       NaN      0.926588              NaN        NaN       NaN
# 21       NaN      1.042466              NaN        NaN       NaN
# 22       NaN      1.189207              NaN        NaN       NaN
# 27  6.430808      0.926588         6.940309   7.832186  1.261303
# 28  8.083612      0.926588         8.724062   7.832186  1.261303
# 29  0.719467      1.042466         0.690159   0.601219  0.125780
# 30  0.609205      1.189207         0.512278   0.601219  0.125780
# 35  0.604997      0.926588         0.652930   0.633186  0.027922
# 36  0.568408      0.926588         0.613442   0.633186  0.027922
# 37  1.370783      1.042466         1.314943   1.067842  0.349453
# 38  0.976032      1.189207         0.820742   1.067842  0.349453
# 43  1.723092      0.926588         1.859610   1.779490  0.113307
# 44  1.574616      0.926588         1.699370   1.779490  0.113307
# 45  1.399586      1.042466         1.342573   1.216540  0.178237
# 46  1.296840      1.189207         1.090508   1.216540  0.178237
# 51  1.361314      0.926588         1.469169   1.516454  0.066872
# 52  1.448942      0.926588         1.563739   1.516454  0.066872
# 53  1.399586      1.042466         1.342573   1.453156  0.156389
# 54  1.859610      1.189207         1.563739   1.453156  0.156389
# 59       NaN      0.926588              NaN        NaN       NaN
# 60       NaN      0.926588              NaN        NaN       NaN
# 61       NaN      1.042466              NaN        NaN       NaN
# 62       NaN      1.189207              NaN        NaN       NaN
# 67  1.176907      0.926588         1.270151   1.199558  0.099834
# 68  1.046085      0.926588         1.128964   1.199558  0.099834
# 69  1.136817      1.042466         1.090508   1.221209  0.184840
# 70  1.607702      1.189207         1.351911   1.221209  0.184840
# 75  1.827663      0.926588         1.972465   1.693339  0.394744
# 76  1.310393      0.926588         1.414214   1.693339  0.394744
# 77  2.751084      1.042466         2.639016   2.944013  0.431331
# 78  3.863745      1.189207         3.249010   2.944013  0.431331
# 83  0.972655      0.926588         1.049717   1.046091  0.005127
# 84  0.965936      0.926588         1.042466   1.046091  0.005127
# 85  0.683020      1.042466         0.655197   0.639681  0.021943
# 86  0.742262      1.189207         0.624165   0.639681  0.021943

# %% [markdown]
# ## Casts
#
# The final element of the EdelweissData™ Query Language are casts, which convert data from one datatype to another. Because the query language uses a simple type system, EdelweissData is able to infer if a cast is possible. If the cast is safe and cannot fail (for example converting an integer to a string), it will be inserted automatically. If the cast is possible, but not necessarily safe (for example converting a string to an integer may fail, or converting a float to an integer will lose data), the user has to insert it explicitly using the \`cast\` function. Its first argument is the expression to cast and the second one is the datatype identifier of the type to cast to.
#
# The possible datatypes are [listed here](/@danyx/edelweissdata-docs-create-and-publish-a-dataset#3-upload-the-schema).

# %%
filter = (Q.cast(Q.column("new_cases"), "xsd:integer") > 50000)

data_cast = dataset.get_data(condition = filter)

altair.Chart(data_cast).mark_circle().encode(
        x="date:T",
        y="new_cases",
        color="location",
        tooltip=["location", "date", "new_cases", "new_deaths"]
    ).properties(width=1000)
# Out:
# alt.Chart(...)
